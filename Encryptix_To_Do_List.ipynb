# %% [markdown]
# #**Encryptix Virtual Internship Task submission**
# By **Nilesh Gaddapawar** (ID: EXM126142)
# #**To-Do List**
# using Python Programming

# %% [markdown]
# A To-Do List application is a useful project that helps users manage
# and organize their tasks efficiently. This project aims to create a
# command-line or GUI-based application using Python, allowing users to create, update, and track their to-do lists
#
#
# ---

# %%
def main():
    tasks = []

    while True:
        print("\n===== To-Do List =====")
        print("1. Add Tasks")
        print("2. Update Task")
        print("3. Delete Task")
        print("4. Mark Task as Done")
        print("5. Show Tasks")
        print("6. Exit")

        choice = input("Enter your choice: ")

        try:
            choice = int(choice)
        except ValueError:
            print("Invalid input. Please enter a number between 1 and 6.")
            continue

        if choice < 1 or choice > 6:
            print("Invalid input. Please enter a number between 1 and 6.")
            continue

        if choice == 1:
            num_tasks = int(input("How many tasks do you want to add? "))
            for _ in range(num_tasks):
                task = input("Enter the task: ")
                tasks.append({"task": task, "done": False})
            print("Tasks added!")

        elif choice == 2:
            print("\nTasks:")
            for index, task in enumerate(tasks):
                status = "Done" if task["done"] else "Not Done"
                print(f"{index + 1}. {task['task']} - {status}")

            task_index = int(input("Enter the task number to update: ")) - 1
            if 0 <= task_index < len(tasks):
                task = input("Enter the updated task: ")
                tasks[task_index]["task"] = task
                print("Task updated!")
            else:
                print("Invalid task number.")

        elif choice == 3:
            print("\nTasks:")
            for index, task in enumerate(tasks):
                status = "Done" if task["done"] else "Not Done"
                print(f"{index + 1}. {task['task']} - {status}")

            task_index = int(input("Enter the task number to delete: ")) - 1
            if 0 <= task_index < len(tasks):
                del tasks[task_index]
                print("Task deleted!")
            else:
                print("Invalid task number.")

        elif choice == 4:
            print("\nTasks:")
            for index, task in enumerate(tasks):
                status = "Done" if task["done"] else "Not Done"
                print(f"{index + 1}. {task['task']} - {status}")

            task_index = int(input("Enter the task number to mark as done: ")) - 1
            if 0 <= task_index < len(tasks):
                tasks[task_index]["done"] = True
                print("Task marked as done!")
            else:
                print("Invalid task number.")

        elif choice == 5:
            print("\nTasks:")
            for index, task in enumerate(tasks):
                status = "Done" if task["done"] else "Not Done"
                print(f"{index + 1}. {task['task']} - {status}")

        elif choice == 6:
            print("Exiting the To-Do List.")
            break

if __name__ == "__main__":
    main()
# Out:
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 5
#
# Tasks:
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 1
# How many tasks do you want to add? 5
# Enter the task: wake up by 05:30
# Enter the task: breakfast by 07:30
# Enter the task: office reach by 09:00
# Enter the task: report to boss by 12:30
# Enter the task: go to Gym by 07:00 pm
# Tasks added!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 5
#
# Tasks:
# 1. wake up by 05:30 - Not Done
# 2. breakfast by 07:30 - Not Done
# 3. office reach by 09:00 - Not Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 2
#
# Tasks:
# 1. wake up by 05:30 - Not Done
# 2. breakfast by 07:30 - Not Done
# 3. office reach by 09:00 - Not Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to update: 3
# Enter the updated task: bath by 08:00
# Task updated!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 4
#
# Tasks:
# 1. wake up by 05:30 - Not Done
# 2. breakfast by 07:30 - Not Done
# 3. bath by 08:00 - Not Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to mark as done: 1
# Task marked as done!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 4
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Not Done
# 3. bath by 08:00 - Not Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to mark as done: 2
# Task marked as done!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 4
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Done
# 3. bath by 08:00 - Not Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to mark as done: 3
# Task marked as done!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 4
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Done
# 3. bath by 08:00 - Done
# 4. report to boss by 12:30 - Not Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to mark as done: 4
# Task marked as done!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 5
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Done
# 3. bath by 08:00 - Done
# 4. report to boss by 12:30 - Done
# 5. go to Gym by 07:00 pm - Not Done
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 3
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Done
# 3. bath by 08:00 - Done
# 4. report to boss by 12:30 - Done
# 5. go to Gym by 07:00 pm - Not Done
# Enter the task number to delete: 3
# Task deleted!
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 5
#
# Tasks:
# 1. wake up by 05:30 - Done
# 2. breakfast by 07:30 - Done
# 3. report to boss by 12:30 - Done
# 4. go to Gym by 07:00 pm - Not Done
#
# ===== To-Do List =====
# 1. Add Tasks
# 2. Update Task
# 3. Delete Task
# 4. Mark Task as Done
# 5. Show Tasks
# 6. Exit
# Enter your choice: 6
# Exiting the To-Do List.
